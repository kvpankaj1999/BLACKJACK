# %%
import random

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
         'Queen':10, 'King':10, 'Ace':11}

playing=True

# %%
class Card:
    def __init__(self,suit,rank):
        self.suit=suit
        self.rank=rank
    def __str__(self):
        return self.rank+" of "+self.suit

# %%
class Deck:
    def __init__(self):
        self.deck=[]
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))
    
    def __str__(self):
        deck_comp=""
        for card in self.deck:
            deck_comp+="\n"+card.__str__()
        return "The Deck has:\n "+deck_comp
    
    def shuffle(self):
        random.shuffle(self.deck)
    
    def deal(self):
        single_card=self.deck.pop()
        return single_card

# %%
 class Hand:
        def __init__(self):
            self.cards=[]
            self.value=0
            self.aces=0
        def add_card(self,card):
            self.cards.append(card)
            self.value+=values[card.rank]
            if card.rank=="Ace":
                self.aces+=1
        def adjust_for_ace(self):
            while self.value>21 and self.aces:
                self.value-=10
                self.aces-=1

# %%
class Chips:
    def __init__(self,total=100):
        self.total=total
        self.bet=0
    def win_bet(self):
        self.total+=self.bet
    def lose_bet(self):
        self.total-=self.bet

# %%
def take_bet(chips):
    while True:
        try:
            chips.bet=int(input("How much would you like to bet : "))
        except:
            print("Enter an integer amount")
        else:
            if chips.bet>chips.total:
                print(f"Sorry you do not have enough to bet that much.You are {chips.total-chips.bet} chips short ")
            else:
                break

# %%
def hit(deck,hand):
    single_card=deck.deal()
    hand.add_card(single_card)
    hand.adjust_for_ace()

# %%
def hit_or_stand(deck,hand):
    global playing
    while True:
        x=input("Hit or Stand? Enter h or s : ")
        if x[0].lower()=="h":
            hit(deck,hand)
        elif x[0].lower()=="s":
            print("Player stands")
            playing=False
        else:
            print("Please enter either h or s")
            continue
        break

# %%
def player_busts(player,dealer,chips):
    print("Player Busts")
    chips.lose_bet()
def player_wins(player,dealer,chips):
    print("Player Wins")
    chips.win_bet()
def dealer_wins(player,dealer,chips):
    print("Dealer Wins")
    chips.lose_bet()
def dealer_busts(player,dealer,chips):
    print("Dealer Busts!! Player wins")
    chips.win_bet()
def push(player,dealer,chips):
    print("Player and Dealer tie")
    chips.win_bet()

# %%
def show_some(player,dealer):
    print("Dealer's hand:\n")
    print("One card is hidden")
    print(dealer.cards[1])
    print("\n")
    print("Player's Hand:\n")
    for card in player.cards:
        print(card)
        
        
def show_all(player,dealer):
    print("Dealer's Hand:\n")
    for card in dealer.cards:
        print(card)
    print("\n")
    print("Player's Hand:\n")
    for card in player.cards:
        print(card)

# %%
playing=True
while True:
    print("----------------Welcome to Blackjack-----------------")
    deck=Deck()
    deck.shuffle()
    print("Cards have been shuffled\n")
    print("You have 100 chips left\n")
    player_chips=Chips()
    while True:


        player_hand=Hand()
        player_hand.add_card(deck.deal())
        player_hand.add_card(deck.deal())

        dealer_hand=Hand()
        dealer_hand.add_card(deck.deal())
        dealer_hand.add_card(deck.deal())

        
        take_bet(player_chips)

        show_some(player_hand,dealer_hand)

        while playing:

            hit_or_stand(deck,player_hand)
            show_some(player_hand,dealer_hand)

            if player_hand.value>21:
                player_busts(player_hand,dealer_hand,player_chips)
                break
        if player_hand.value<=21:
            while dealer_hand.value<player_hand.value:
                hit(deck,dealer_hand)
            show_all(player_hand,dealer_hand)
            if dealer_hand.value>21:
                dealer_busts(player_hand,dealer_hand,player_chips)
            elif dealer_hand.value>player_hand.value:
                dealer_wins(player_hand,dealer_hand,player_chips)
            else:
                push(player_hand,dealer_hand,player_chips)



        print(f"\n Player has {player_chips.total} left with him")
        if player_hand.value>0:
            new_round=input("Would you like to play another round? Yes or No : ")
        if new_round[0].lower()=="y":
            playing=True
            continue
        else:
            print(f"Thank you for playing!. You have won {player_chips.total}")
            break
    new_game=input("Would you like to play another game? Yes or No : ")
    if new_game[0].lower()=="y":
        playing=True
        continue
    else:
        print(f"Thank you for playing!. You have won {player_chips.total}")
        break
# Out:
# ----------------Welcome to Blackjack-----------------
# Cards have been shuffled
#
# You have 100 chips left
#
# How much would you like to bet : 100
# Dealer's hand:
#
# One card is hidden
# Ten of Spades
#
#
# Player's Hand:
#
# Queen of Spades
# Seven of Diamonds
# Hit or Stand? Enter h or s : s
# Player stands
# Dealer's hand:
#
# One card is hidden
# Ten of Spades
#
#
# Player's Hand:
#
# Queen of Spades
# Seven of Diamonds
# Dealer's Hand:
#
# Eight of Hearts
# Ten of Spades
#
#
# Player's Hand:
#
# Queen of Spades
# Seven of Diamonds
# Dealer Wins
#
#  Player has 0 left with him
# Would you like to play another round? Yes or No : no
# Thank you for playing!. You have won 0
# Would you like to play another game? Yes or No : no
# Thank you for playing!. You have won 0
